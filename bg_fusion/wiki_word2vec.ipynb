# %%
import logging
import os.path
import sys
import os
import multiprocessing
from gensim.corpora import WikiCorpus
from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence

# %%
logger = logging.getLogger("wiki_word2vec")
logging.basicConfig(format='%(asctime)s: %(levelname)s: %(message)s')
logging.root.setLevel(level=logging.INFO)

# %%
output = open("E:/kaggle/avito/imdb_testset/wiki.en.text", 'w')
wiki = WikiCorpus("E:/kaggle/avito/imdb_testset/enwiki-latest-pages-articles.xml.bz2", lemmatize=False, dictionary={})
# Out:
# 2018-05-26 00:19:40,511: INFO: adding document #0 to Dictionary(0 unique tokens: [])
# 2018-05-26 00:21:04,167: INFO: adding document #10000 to Dictionary(447789 unique tokens: ['abandoning', 'abandonment', 'abdelrahim', 'abdullah', 'ability']...)
# 2018-05-26 00:22:16,976: INFO: adding document #20000 to Dictionary(643470 unique tokens: ['abandoning', 'abandonment', 'abdelrahim', 'abdullah', 'ability']...)
# 2018-05-26 00:23:17,991: INFO: adding document #30000 to Dictionary(781861 unique tokens: ['abandoning', 'abandonment', 'abdelrahim', 'abdullah', 'ability']...)
# 2018-05-26 00:24:14,670: INFO: adding document #40000 to Dictionary(905719 unique tokens: ['abandoning', 'abandonment', 'abdelrahim', 'abdullah', 'ability']...)
# 2018-05-26 00:24:58,661: INFO: adding document #50000 to Dictionary(985940 unique tokens: ['abandoning', 'abandonment', 'abdelrahim', 'abdullah', 'ability']...)
# ...

# %%
for text in wiki.get_texts():
    output.write(b' '.join(text).decode('utf-8') + '\n')
    i = i + 1
    if (i % 10000 == 0):
        logger.info("Saved " + str(i) + " articles")
output.close()
logger.info("Finished Saved " + str(i) + " articles")

# %%
model = Word2Vec(LineSentence("E:/kaggle/avito/imdb_testset/wiki.en.text"), size=400, window=5, min_count=5, workers=multiprocessing.cpu_count())
model.save("E:/kaggle/avito/imdb_testset/wiki.en.text.model")

# %%
model.wv.save_word2vec_format("E:/kaggle/avito/imdb_testset/wiki.en.text.vector", binary=False)
